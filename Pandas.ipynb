# %% [markdown]
# # Pandas 🐼
#
# Studying one of most important libraries of Data Analysis and Data Visualization in Python: The Pandas.
#
# by: Pedro Florencio
#
# ---

# %% [markdown]
# <b> How to import? <b/>

# %%
import pandas as pd

# %% [markdown]
# <b> How to create a Series? <b/>

# %%
myIndex = ['a','b','c'] # We can use list, array or dict
myList = [10,20,30]

# %%
mySerie = pd.Series(data=myList, index=myIndex)
mySerie
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
mySerie['a'] # Access to data
# Out:
# 10

# %%
countries = pd.Series(index=['Brasil', 'Argentina', 'URSS'], data=[0,1,2])
countries
# Out:
# Brasil       0
# Argentina    1
# URSS         2
# dtype: int64

# %%
countries2 = pd.Series(index=['Brasil', 'Argentina', 'Italia'], data=[2,4,6])
countries2
# Out:
# Brasil       2
# Argentina    4
# Italia       6
# dtype: int64

# %% [markdown]
# <b> How to do Series operations? <b/>

# %%
soma = countries+countries2
soma
# Out:
# Argentina    5.0
# Brasil       2.0
# Italia       NaN
# URSS         NaN
# dtype: float64

# %% [markdown]
# <b> How to create a DataFrame? <b/>

# %%
import numpy as np

mylist2 = ['Pedro','Maria','João','Karol', 'Junior','Manoel','Aline','Geralda','Alana']
a = np.array(lista)
names = a.reshape(3,3)

df = pd.DataFrame(data= names,index=['A','B','C'], columns=[1,2,3])
df
# Out:
#        1        2       3
# A  Pedro    Maria    João
# B  Karol   Junior  Manoel
# C  Aline  Geralda   Alana

# %% [markdown]
# <b> How to access data from a DataFrame? <b/>

# %%
df[2] # For columns
# Out:
# A      Maria
# B     Junior
# C    Geralda
# Name: 2, dtype: object

# %%
df.loc['A'] # For lines (index)
# Out:
# 1    Pedro
# 2    Maria
# 3     João
# Name: A, dtype: object

# %%
df.iloc[0] # For lines, but with number of index
# Out:
# 1    Pedro
# 2    Maria
# 3     João
# Name: A, dtype: object

# %%
df.loc[['A','B'],[1,3]] # Slicing of a DataFrame
# Out:
#        1       3
# A  Pedro    João
# B  Karol  Manoel

# %% [markdown]
# <b> How to reset index? <b/>

# %%
df.reset_index(inplace=True)
df
# Out:
#   index      1        2       3
# 0     A  Pedro    Maria    João
# 1     B  Karol   Junior  Manoel
# 2     C  Aline  Geralda   Alana

# %% [markdown]
# <b> How to add a column? <b/>

# %%
col = ['Wow','I am','New']
df[4] = col
df
# Out:
#   index      1        2       3     4
# 0     A  Pedro    Maria    João   Wow
# 1     B  Karol   Junior  Manoel  I am
# 2     C  Aline  Geralda   Alana   New

# %%
df.set_index(4,inplace=True) # The column is a new index

# %%
df
# Out:
#      index      1        2       3
# 4
# Wow      A  Pedro    Maria    João
# I am     B  Karol   Junior  Manoel
# New      C  Aline  Geralda   Alana

# %% [markdown]
# <b> Missing data <b/>

# %%
d = {'A':[1,2,np.nan],'B':[5,np.nan,np.nan],'C':[1,2,3]}

# %%
df = pd.DataFrame(d)

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.dropna(thresh=2) # It removes all lines containing 2 NaN
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2

# %%
df.fillna(value=0) #  It replaces all NaN with the value
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  0.0  2
# 2  0.0  0.0  3

# %%
df.fillna(method='ffill') # It replaces NaN with the last valid observation
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  5.0  2
# 2  2.0  5.0  3

# %% [markdown]
# <b> Group By <b/>

# %%
data = {'Company':['GOOGLE','GOOGLE','MSTF','MSTF','FB','FB'],
         'Name':['Sam','Charlie','Amy','Vanessa','Carl','Sarah'],
        'Sales':[200,120,340,124,243,350]}

# %%
df = pd.DataFrame(data)
df
# Out:
#   Company     Name  Sales
# 0  GOOGLE      Sam    200
# 1  GOOGLE  Charlie    120
# 2    MSTF      Amy    340
# 3    MSTF  Vanessa    124
# 4      FB     Carl    243
# 5      FB    Sarah    350

# %%
group = df.groupby('Company')

# %%
group.sum()
# Out:
#          Sales
# Company
# FB         593
# GOOGLE     320
# MSTF       464

# %% [markdown]
# <b> Concatenating/Joining/Merging <b/>

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3'],
                        'C': ['C0', 'C1', 'C2', 'C3'],
                        'D': ['D0', 'D1', 'D2', 'D3']},
                        index=[0, 1, 2, 3])

# %%
df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                        'B': ['B4', 'B5', 'B6', 'B7'],
                        'C': ['C4', 'C5', 'C6', 'C7'],
                        'D': ['D4', 'D5', 'D6', 'D7']},
                         index=[4, 5, 6, 7])

# %%
df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                        'B': ['B8', 'B9', 'B10', 'B11'],
                        'C': ['C8', 'C9', 'C10', 'C11'],
                        'D': ['D8', 'D9', 'D10', 'D11']},
                        index=[8, 9, 10, 11])

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df3
# Out:
#       A    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
pd.concat([df1,df2,df3])
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
left = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                     'A': ['A0', 'A1', 'A2', 'A3'],
                     'B': ['B0', 'B1', 'B2', 'B3']})
   
right = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                          'C': ['C0', 'C1', 'C2', 'C3'],
                          'D': ['D0', 'D1', 'D2', 'D3']})

# %%
pd.merge(left,right,how='inner',on='key')
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2
# 3  K3  A3  B3  C3  D3

# %%
left = pd.DataFrame({'A': ['A0', 'A1', 'A2'],
                     'B': ['B0', 'B1', 'B2']},
                      index=['K0', 'K1', 'K2']) 

right = pd.DataFrame({'C': ['C0', 'C2', 'C3'],
                    'D': ['D0', 'D2', 'D3']},
                      index=['K0', 'K2', 'K3'])

# %%
left.join(right)
# Out:
#      A   B    C    D
# K0  A0  B0   C0   D0
# K1  A1  B1  NaN  NaN
# K2  A2  B2   C2   D2

# %%
left.join(right,how='outer')
# Out:
#       A    B    C    D
# K0   A0   B0   C0   D0
# K1   A1   B1  NaN  NaN
# K2   A2   B2   C2   D2
# K3  NaN  NaN   C3   D3

# %% [markdown]
# <b> Operations <b/>

# %%
df = pd.DataFrame({'col1':[1,2,3,4],'col2':[444,555,666,444],'col3':['abc','def','ghi','xyz']})
df
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df['col2'].unique() # Selecting unique values
# Out:
# array([444, 555, 666], dtype=int64)

# %%
df['col2'].nunique()
# Out:
# 3

# %%
df['col2'].value_counts()
# Out:
# 444    2
# 555    1
# 666    1
# Name: col2, dtype: int64

# %%
def vezes2 (x):
    return x*2

# %%
df['col1'].apply(vezes2)
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# Name: col1, dtype: int64

# %%
df['col1'].apply(lambda x : x*2)
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# Name: col1, dtype: int64

# %%
df.columns
# Out:
# Index(['col1', 'col2', 'col3'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df.sort_values(by='col2')
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 3     4   444  xyz
# 1     2   555  def
# 2     3   666  ghi

# %% [markdown]
# <b> Input/Output <b/>

# %%
df = pd.read_csv('genres.csv')
df.head()
# Out:
# C:\Users\pedro\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (19) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.831   0.814    2    -7.364     1       0.4200        0.0598
# 1         0.719   0.493    8    -7.230     1       0.0794        0.4010
# 2         0.850   0.893    5    -4.783     1       0.0623        0.0138
# 3         0.476   0.781    0    -4.710     1       0.1030        0.0237
# 4         0.798   0.624    2    -7.668     1       0.2930        0.2170
#
#    instrumentalness  liveness  valence  ...                      id  \
# 0          0.013400    0.0556   0.3890  ...  2Vc6NJ9PW9gD9q343XFRKx
# 1          0.000000    0.1180   0.1240  ...  7pgJBLVz5VmnL7uGHmRj6p
# 2          0.000004    0.3720   0.0391  ...  0vSWgAlfpye0WCGeNmuNhy
# ...

# %%
len(df)
# Out:
# 42305
